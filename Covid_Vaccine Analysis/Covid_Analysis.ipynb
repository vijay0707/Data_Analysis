# %% [markdown]
# # COVID-19 VACCINE ANALYSIS
#
# Vaccines plays a vital role in controlling Covid-19. Many countries are trying different vaccines though No vaccine is not 100% accuracy. Still, It will save our life by increasing immunity.
#
# ## Analysis with python
#
# The dataset used here is taken from Kaggle(https://www.kaggle.com/gpreda/covid-world-vaccination-progress).
#
# We are going to analyse how many vaccines each country is using to fight covid-19

# %%
# importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the dataset

df = pd.read_csv('country_vaccinations.csv')
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
# Statistical Info
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.416100e+04       1.344500e+04             1.070700e+04
# mean         8.822304e+06       4.622017e+06             2.610813e+06
# std          4.369827e+07       1.762479e+07             1.074058e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          9.600700e+04       7.633600e+04             3.534650e+04
# 50%          6.765010e+05       4.993840e+05             2.717550e+05
# 75%          3.150122e+06       2.091511e+06             1.158264e+06
# max          9.666520e+08       6.220000e+08             2.232990e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.170800e+04        2.494800e+04
# mean             1.970966e+05        1.000137e+05
# std              1.085285e+06        7.091565e+05
# min              0.000000e+00        0.000000e+00
# 25%              3.918750e+03        8.347500e+02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25240 entries, 0 to 25239
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              25240 non-null  object
#  1   iso_code                             25240 non-null  object
#  2   date                                 25240 non-null  object
#  3   total_vaccinations                   14161 non-null  float64
#  4   people_vaccinated                    13445 non-null  float64
#  5   people_fully_vaccinated              10707 non-null  float64
#  6   daily_vaccinations_raw               11708 non-null  float64
#  7   daily_vaccinations                   24948 non-null  float64
#  8   total_vaccinations_per_hundred       14161 non-null  float64
#  9   people_vaccinated_per_hundred        13445 non-null  float64
#  10  people_fully_vaccinated_per_hundred  10707 non-null  float64
# ...

# %%
# Count of Countries
df.country.value_counts()
# Out:
# Norway                             197
# Scotland                           189
# Canada                             186
# China                              185
# Russia                             185
#                                   ...
# Burkina Faso                        13
# Chad                                 1
# Turkmenistan                         1
# Bonaire Sint Eustatius and Saba      1
# Pitcairn                             1
# Name: country, Length: 217, dtype: int64

# %%
pd.to_datetime(df.date)
# Out:
# 0       2021-02-22
# 1       2021-02-23
# 2       2021-02-24
# 3       2021-02-25
# 4       2021-02-26
#            ...
# 25235   2021-06-10
# 25236   2021-06-11
# 25237   2021-06-12
# 25238   2021-06-13
# 25239   2021-06-14
# Name: date, Length: 25240, dtype: datetime64[ns]

# %%
# Vaccine counts:
df.vaccines.value_counts()
# Out:
# Oxford/AstraZeneca                                                                             4199
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                  3384
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                                   2174
# Oxford/AstraZeneca, Pfizer/BioNTech                                                            1777
# Moderna, Pfizer/BioNTech                                                                       1368
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                              1216
# Pfizer/BioNTech                                                                                1086
# Oxford/AstraZeneca, Sinopharm/Beijing                                                          1060
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                                   1011
# ...

# %%
# Create a new Dataframe by only selecting the vaccine and the country columns to find which country is taken by which country

data = df[['vaccines', 'country']]
data.head(10)
# data[data['country']=='India']
# Out:
#                                           vaccines      country
# 0  BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech  Afghanistan
# 1  BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech  Afghanistan
# 2  BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech  Afghanistan
# 3  BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech  Afghanistan
# 4  BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech  Afghanistan
# 5  BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech  Afghanistan
# 6  BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech  Afghanistan
# 7  BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech  Afghanistan
# 8  BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech  Afghanistan
# 9  BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech  Afghanistan

# %% [markdown]
# ### let’s see how many countries are taking each of the vaccines mentioned in this data:

# %%
dict_ = {}
for i in df.vaccines.unique():
    dict_[i]=[df["country"][j] for j in df[df["vaccines"]==i].index]
    
vaccines = {}
for key, value in dict_.items():
      vaccines[key] = set(value)
for i, j in vaccines.items():
      print(f"{i}:>>{j}")
# Out:
# BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Afghanistan'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Albania', 'Bosnia and Herzegovina', 'Philippines', 'Tunisia'}
# Oxford/AstraZeneca, Sputnik V:>>{'Guyana', 'Nicaragua', 'Algeria', 'Ghana', 'Kenya'}
# Oxford/AstraZeneca, Pfizer/BioNTech:>>{'South Korea', 'Andorra', 'Oman', 'Panama', 'Cape Verde', 'Saudi Arabia', 'Costa Rica', 'Slovenia', 'Australia', 'Isle of Man', 'Cayman Islands', 'Sweden'}
# ...

# %% [markdown]
# ### Visualizing this data to look at what combination of vaccines every county is using:

# %%
# using Plotly
import plotly.express as px
import plotly.offline as py

vaccine_map = px.choropleth(df, locations = 'iso_code', color = 'vaccines')
vaccine_map.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
vaccine_map.show()
# Out:
# <div>                            <div id="d085dfbe-d162-4b66-a503-9fff3cba858a" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d085dfbe-d162-4b66-a503-9fff3cba858a")) {                    Plotly.newPlot(                        "d085dfbe-d162-4b66-a503-9fff3cba858a",                        [{"colorscale": [[0.0, "#636efa"], [1.0, "#636efa"]], "geo": "geo", "hovertemplate": "vaccines=BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech<br>iso_code=%{location}<extra></extra>", "locations": ["AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG
# ...

# %% [markdown]
# <span> Note: We can also draw more insights from the data. <span>
